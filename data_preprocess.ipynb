# %%
import pandas as pd

df = pd.read_csv(".\src\assets\netflix_titles.csv")

titles = [
"Squid Game","Stranger Things","The Witcher","Money Heist","Bridgerton",
"The Queen's Gambit","Dark","Lupin","Black Mirror","Narcos",
"Kingdom","Alice in Borderland","Vincenzo","Itaewon Class",
"Crash Landing on You","Love, Death & Robots","The Crown",
"Bird Box","The Irishman","Okja"
]

filtered = df[df["title"].isin(titles)]

filtered.to_csv("netflix_korea_popular_20.csv", index=False)
